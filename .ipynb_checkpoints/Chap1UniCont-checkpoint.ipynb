# %% [markdown]
# # Chapter 1 Unidimentional continuous variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.1 Histogram

# %% [markdown]
# ### 1.1.1 Basics

# %%
titanic = sns.load_dataset('titanic')
sns.histplot(data=titanic, x ="age")
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>
